# %%
from keras.datasets import mnist
(train_images ,train_labels),(test_images ,test_labels) = mnist.load_data()

# %%
train_images.shape

# %%
len(train_images)

# %%
train_images

# %%
train_labels

# %%
test_images.shape

# %%
len(test_images)

# %%
test_labels

# %%
 from keras import models
 from keras import layers

# %%
network = models.Sequential()
network.add(layers.Dense(512,activation="relu",input_shape = (28*28,)))
network.add(layers.Dense(10,activation="softmax"))

# %%
network.compile(optimizer="rmsprop",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
train_images = train_images.reshape((60000,28*28))
train_images = train_images.astype("float32")/255

test_images = test_images.reshape((10000,28*28))
test_images = test_images.astype("float32")/255

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images,train_labels,epochs=10,batch_size=128)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 2/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 3/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0014 - accuracy: 0.9997
# Epoch 4/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 5/10
# 469/469 [==============================] - 4s 9ms/step - loss: 8.8624e-04 - accuracy: 0.9998
# Epoch 6/10
# 469/469 [==============================] - 4s 9ms/step - loss: 9.3757e-04 - accuracy: 0.9998
# Epoch 7/10
# 469/469 [==============================] - 4s 9ms/step - loss: 5.6408e-04 - accuracy: 0.9998
# Epoch 8/10
# 469/469 [==============================] - 4s 9ms/step - loss: 5.2715e-04 - accuracy: 0.9999
# Epoch 9/10
# 469/469 [==============================] - 4s 9ms/step - loss: 4.9099e-04 - accuracy: 0.9998
# Epoch 10/10
# 469/469 [==============================] - 4s 9ms/step - loss: 2.6192e-04 - accuracy: 0.9999

# %%
test_loss,test_accuracy = network.evaluate(test_images,test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1119 - accuracy: 0.9821

# %%
print(test_loss)
# Out:
# 0.11192363500595093

# %%
print(test_accuracy)
# Out:
# 0.9821000099182129
